# %%
import pandas as pd 
import numpy as np
import re

import nltk
from nltk.corpus import stopwords

from bs4 import BeautifulSoup

from numpy import array
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers.core import Activation, Dropout, Dense
from keras.layers import Flatten
from keras.layers import GlobalMaxPooling1D
from keras.layers.embeddings import Embedding
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer

# %%
input_file = '/Users/davidan/Downloads/fade-net/data/fakenews.mit.edu/fake.txt'
output_file = '/Users/davidan/Downloads/fade-net/data/test.csv'
num_columns = 1


file = open(input_file, 'r', encoding = "utf-8")

# Read the file
new_text = file.read()

# Create a list to keep all the words in file
words = new_text.splitlines()
line_break = 0

# Add all the words in file to list
'''for x in range(0, len(new_text)):
    for word in new_text[x].split():
        words.append(word + ',')'''


# Write words into csv file
f = open(output_file,'w')
for x in range(0, len(words)):
    if (line_break == num_columns):
        f.write('\n')
        f.write(words[x])
        line_break = 1
    else:
        f.write(words[x])
        line_break += 1
f.close()

# %%
df = pd.read_csv('/Users/davidan/Downloads/fade-net/data/test.csv', header = None, error_bad_lines=False)

# %%
print(df)
# Out:
#                                                        0
# 0                                               bodytext
# 1      In todays of reports on a fake Proof of Life V...
# 2      Ads Privacy Policy On the people will have the...
# 3      By J This is the continuation of the testimony...
# 4      2016 The great thing about modern technology a...
# ...                                                  ...
# 10440  2016 0 0 Signs of the times. This past Musks c...
# 10441  While forces are advancing in to free the some...
# 10442  The article reports that there will be premium...
# 10443  This post was originally published on this sit...
# 10444  This post was originally published on this sit...
#
# [10445 rows x 1 columns]

# %%
df.to_csv('/Users/davidan/Downloads/fade-net/data/test.csv', header = ['bodytext'], index = False)
